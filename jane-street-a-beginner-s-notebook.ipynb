# %% [markdown]
# # Mainly for model training
#
# Depending on the size of your training set, you will need an [inference notebook](https://www.kaggle.com/code/regisvargas/inference-jane-street-a-beginner-s-notebook).

# %%
import pandas as pd
# Initialize a list to hold samples from each file
samples = []
# Load a sample from each file
for i in range(10):
    file_path = f"/kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet/partition_id={i}/part-0.parquet"
    chunk = pd.read_parquet(file_path)
    
    # Take a sample of the data (adjust sample size as needed)
    sample_chunk = chunk.sample(n=500000, random_state=42)  # For example, 100 rows
    samples.append(sample_chunk)
# Concatenate all samples into one DataFrame if needed
sample_df = pd.concat(samples, ignore_index=True)

# %%
sample_df.head()
# Out:
#    date_id  time_id  symbol_id    weight  feature_00  feature_01  feature_02  \
# 0       85      288         38  3.119714         NaN         NaN         NaN
# 1       83       69          0  2.372535         NaN         NaN         NaN
# 2       82      199         16  1.943764         NaN         NaN         NaN
# 3        0      779          9  2.285698         NaN         NaN         NaN
# 4      169      178          7  1.789037         NaN         NaN         NaN
#
#    feature_03  feature_04  feature_05  ...  feature_78  responder_0  \
# 0         NaN         NaN    0.188973  ...   -0.191460     0.386567
# 1         NaN         NaN   -0.249393  ...   -0.304067     2.162238
# 2         NaN         NaN   -0.034782  ...   -0.174753    -0.093317
# 3         NaN         NaN   -0.200830  ...   -0.264010    -0.010857
# 4         NaN         NaN    0.695718  ...   -0.256375    -0.107448
#
#    responder_1  responder_2  responder_3  responder_4  responder_5  \
# 0    -0.180631    -0.394700     0.212311     1.695289    -0.002445
# 1     0.687817     0.344059     2.191972     0.183375     0.511344
# 2    -0.030093    -0.060351    -0.016916     0.141347     0.084314
# 3    -0.047279     0.000333     0.223133     0.273011     0.259631
# 4    -0.852934    -0.150064    -0.000850    -0.035807    -0.328767
#
#    responder_6  responder_7  responder_8
# 0    -0.041428     0.147673     0.352121
# 1     1.261587    -0.337162     0.283835
# 2     0.035796     0.130798     0.339303
# 3     0.265585     0.200747    -0.067575
# 4     0.106589     0.703084    -0.247847
#
# [5 rows x 92 columns]

# %% [markdown]
# # Prepare data

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
# Separate features and responders
features = sample_df.filter(regex='^feature_')
responders = sample_df.filter(regex='^responder_')
weights = sample_df['weight']
# Convert to numpy arrays for TensorFlow
X = features.values  # Features for input
#y = responders.values  # Responders for output
# Assuming you have a DataFrame `y_train` with all responders
y = responders[['responder_6']].values  # Keep only responder_6
X = np.nan_to_num(X, nan=0.0, posinf=0.0, neginf=0.0)
y = np.nan_to_num(y, nan=0.0, posinf=0.0, neginf=0.0)

# %%
Is_keras = False

# %% [markdown]
# # XGBoost
#
# See [Feature engineering, xgboost](https://www.kaggle.com/code/dlarionov/feature-engineering-xgboost#Part-2,-xgboost) for details.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val, weights_train, weights_val = train_test_split(
    X, y, weights, test_size=0.2, random_state=42
)

# %%
# Define a learning rate schedule
def learning_rate_scheduler_xgb(epoch):
    initial_rate = 0.3
    decay_rate = 0.999
    return initial_rate * (decay_rate ** (np.log(epoch)))

# %%
from xgboost import XGBRegressor
# Create an XGBoost model
model_xgb = XGBRegressor(
    n_estimators=1000,
    learning_rate=learning_rate_scheduler_xgb,
    max_depth=8,
    random_state=42
)
# Fit the model with sample weights and validation dataset
model_xgb.fit(
    X_train,
    y_train,
    sample_weight=weights_train,
    eval_set=[(X_train, y_train), (X_val, y_val)],
    sample_weight_eval_set=[weights_train, weights_val],
    eval_metric='rmse',
    early_stopping_rounds=10,
    verbose=True
)
# Out:
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:0.85303	validation_1-rmse:0.85323
# [1]	validation_0-rmse:0.85130	validation_1-rmse:0.85214
# [2]	validation_0-rmse:0.85001	validation_1-rmse:0.85153
# [3]	validation_0-rmse:0.84881	validation_1-rmse:0.85095
# [4]	validation_0-rmse:0.84785	validation_1-rmse:0.85058
# [5]	validation_0-rmse:0.84705	validation_1-rmse:0.85031
# [6]	validation_0-rmse:0.84619	validation_1-rmse:0.84999
# [7]	validation_0-rmse:0.84552	validation_1-rmse:0.84982
# [8]	validation_0-rmse:0.84475	validation_1-rmse:0.84957
# [9]	validation_0-rmse:0.84404	validation_1-rmse:0.84927
# [10]	validation_0-rmse:0.84343	validation_1-rmse:0.84909
# [11]	validation_0-rmse:0.84280	validation_1-rmse:0.84891
# [12]	validation_0-rmse:0.84211	validation_1-rmse:0.84873
# [13]	validation_0-rmse:0.84140	validation_1-rmse:0.84854
# [14]	validation_0-rmse:0.84092	validation_1-rmse:0.84840
# [15]	validation_0-rmse:0.84032	validation_1-rmse:0.84822
# [16]	validation_0-rmse:0.83978	validation_1-rmse:0.84815
# [17]	validation_0-rmse:0.83921	validation_1-rmse:0.84810
# [18]	validation_0-rmse:0.83871	validation_1-rmse:0.84794
# [19]	validation_0-rmse:0.83805	validation_1-rmse:0.84784
# [20]	validation_0-rmse:0.83750	validation_1-rmse:0.84769
# [21]	validation_0-rmse:0.83695	validation_1-rmse:0.84760
# [22]	validation_0-rmse:0.83640	validation_1-rmse:0.84747
# [23]	validation_0-rmse:0.83545	validation_1-rmse:0.84695
# [24]	validation_0-rmse:0.83511	validation_1-rmse:0.84685
# [25]	validation_0-rmse:0.83447	validation_1-rmse:0.84661
# [26]	validation_0-rmse:0.83402	validation_1-rmse:0.84657
# [27]	validation_0-rmse:0.83353	validation_1-rmse:0.84653
# [28]	validation_0-rmse:0.83312	validation_1-rmse:0.84647
# [29]	validation_0-rmse:0.83266	validation_1-rmse:0.84635
# [30]	validation_0-rmse:0.83220	validation_1-rmse:0.84632
# [31]	validation_0-rmse:0.83176	validation_1-rmse:0.84625
# [32]	validation_0-rmse:0.83134	validation_1-rmse:0.84620
# [33]	validation_0-rmse:0.83084	validation_1-rmse:0.84612
# [34]	validation_0-rmse:0.83059	validation_1-rmse:0.84607
# [35]	validation_0-rmse:0.83006	validation_1-rmse:0.84600
# [36]	validation_0-rmse:0.82965	validation_1-rmse:0.84593
# [37]	validation_0-rmse:0.82916	validation_1-rmse:0.84583
# [38]	validation_0-rmse:0.82855	validation_1-rmse:0.84557
# [39]	validation_0-rmse:0.82819	validation_1-rmse:0.84550
# [40]	validation_0-rmse:0.82770	validation_1-rmse:0.84535
# [272]	validation_0-rmse:0.76243	validation_1-rmse:0.83627
# [273]	validation_0-rmse:0.76221	validation_1-rmse:0.83623
# [274]	validation_0-rmse:0.76200	validation_1-rmse:0.83623
# [275]	validation_0-rmse:0.76182	validation_1-rmse:0.83621
# [276]	validation_0-rmse:0.76157	validation_1-rmse:0.83617
# [277]	validation_0-rmse:0.76132	validation_1-rmse:0.83613
# [278]	validation_0-rmse:0.76111	validation_1-rmse:0.83609
# [279]	validation_0-rmse:0.76094	validation_1-rmse:0.83611
# [280]	validation_0-rmse:0.76068	validation_1-rmse:0.83605
# [281]	validation_0-rmse:0.76048	validation_1-rmse:0.83607
# [282]	validation_0-rmse:0.76028	validation_1-rmse:0.83605
# [283]	validation_0-rmse:0.76001	validation_1-rmse:0.83602
# [284]	validation_0-rmse:0.75977	validation_1-rmse:0.83601
# [285]	validation_0-rmse:0.75957	validation_1-rmse:0.83602
# [286]	validation_0-rmse:0.75938	validation_1-rmse:0.83600
# [287]	validation_0-rmse:0.75912	validation_1-rmse:0.83601
# [288]	validation_0-rmse:0.75897	validation_1-rmse:0.83600
# [289]	validation_0-rmse:0.75879	validation_1-rmse:0.83602
# [290]	validation_0-rmse:0.75867	validation_1-rmse:0.83603
# [291]	validation_0-rmse:0.75839	validation_1-rmse:0.83600
# [292]	validation_0-rmse:0.75818	validation_1-rmse:0.83601
# [293]	validation_0-rmse:0.75801	validation_1-rmse:0.83602
# [294]	validation_0-rmse:0.75775	validation_1-rmse:0.83602
# [295]	validation_0-rmse:0.75752	validation_1-rmse:0.83598
# [296]	validation_0-rmse:0.75726	validation_1-rmse:0.83597
# [297]	validation_0-rmse:0.75710	validation_1-rmse:0.83593
# [298]	validation_0-rmse:0.75690	validation_1-rmse:0.83591
# [299]	validation_0-rmse:0.75667	validation_1-rmse:0.83588
# [300]	validation_0-rmse:0.75640	validation_1-rmse:0.83586
# [301]	validation_0-rmse:0.75620	validation_1-rmse:0.83588
# [302]	validation_0-rmse:0.75605	validation_1-rmse:0.83585
# [303]	validation_0-rmse:0.75584	validation_1-rmse:0.83583
# [304]	validation_0-rmse:0.75567	validation_1-rmse:0.83584
# [305]	validation_0-rmse:0.75549	validation_1-rmse:0.83584
# [306]	validation_0-rmse:0.75526	validation_1-rmse:0.83582
# [307]	validation_0-rmse:0.75505	validation_1-rmse:0.83580
# [308]	validation_0-rmse:0.75486	validation_1-rmse:0.83580
# [309]	validation_0-rmse:0.75467	validation_1-rmse:0.83579
# [310]	validation_0-rmse:0.75444	validation_1-rmse:0.83573
# [311]	validation_0-rmse:0.75421	validation_1-rmse:0.83574
# [312]	validation_0-rmse:0.75397	validation_1-rmse:0.83570
# [313]	validation_0-rmse:0.75374	validation_1-rmse:0.83565
# [314]	validation_0-rmse:0.75354	validation_1-rmse:0.83559
# [315]	validation_0-rmse:0.75334	validation_1-rmse:0.83559
# [316]	validation_0-rmse:0.75315	validation_1-rmse:0.83561
# [317]	validation_0-rmse:0.75294	validation_1-rmse:0.83560
# [318]	validation_0-rmse:0.75277	validation_1-rmse:0.83559
# [319]	validation_0-rmse:0.75257	validation_1-rmse:0.83557
# [320]	validation_0-rmse:0.75234	validation_1-rmse:0.83553
# [321]	validation_0-rmse:0.75213	validation_1-rmse:0.83554
# [322]	validation_0-rmse:0.75192	validation_1-rmse:0.83553
# [323]	validation_0-rmse:0.75175	validation_1-rmse:0.83552
# [324]	validation_0-rmse:0.75161	validation_1-rmse:0.83549
# [325]	validation_0-rmse:0.75142	validation_1-rmse:0.83552
# [326]	validation_0-rmse:0.75121	validation_1-rmse:0.83552
# [327]	validation_0-rmse:0.75099	validation_1-rmse:0.83550
# [328]	validation_0-rmse:0.75074	validation_1-rmse:0.83549
# [329]	validation_0-rmse:0.75055	validation_1-rmse:0.83549
# [330]	validation_0-rmse:0.75038	validation_1-rmse:0.83550
# [331]	validation_0-rmse:0.75021	validation_1-rmse:0.83545
# [332]	validation_0-rmse:0.75007	validation_1-rmse:0.83547
# [333]	validation_0-rmse:0.74985	validation_1-rmse:0.83544
# [334]	validation_0-rmse:0.74966	validation_1-rmse:0.83542
# [335]	validation_0-rmse:0.74942	validation_1-rmse:0.83537
# [336]	validation_0-rmse:0.74924	validation_1-rmse:0.83536
# [337]	validation_0-rmse:0.74903	validation_1-rmse:0.83531
# [338]	validation_0-rmse:0.74877	validation_1-rmse:0.83530
# [339]	validation_0-rmse:0.74854	validation_1-rmse:0.83530
# [340]	validation_0-rmse:0.74835	validation_1-rmse:0.83527
# [341]	validation_0-rmse:0.74807	validation_1-rmse:0.83521
# [342]	validation_0-rmse:0.74790	validation_1-rmse:0.83521
# [343]	validation_0-rmse:0.74773	validation_1-rmse:0.83521
# [344]	validation_0-rmse:0.74755	validation_1-rmse:0.83521
# [345]	validation_0-rmse:0.74734	validation_1-rmse:0.83522
# [346]	validation_0-rmse:0.74714	validation_1-rmse:0.83520
# [347]	validation_0-rmse:0.74696	validation_1-rmse:0.83519
# [348]	validation_0-rmse:0.74673	validation_1-rmse:0.83520
# [349]	validation_0-rmse:0.74652	validation_1-rmse:0.83518
# [350]	validation_0-rmse:0.74633	validation_1-rmse:0.83514
# [351]	validation_0-rmse:0.74611	validation_1-rmse:0.83512
# [352]	validation_0-rmse:0.74592	validation_1-rmse:0.83510
# [353]	validation_0-rmse:0.74573	validation_1-rmse:0.83509
# [354]	validation_0-rmse:0.74551	validation_1-rmse:0.83508
# [355]	validation_0-rmse:0.74532	validation_1-rmse:0.83506
# [356]	validation_0-rmse:0.74511	validation_1-rmse:0.83503
# [357]	validation_0-rmse:0.74492	validation_1-rmse:0.83500
# [358]	validation_0-rmse:0.74467	validation_1-rmse:0.83497
# [359]	validation_0-rmse:0.74448	validation_1-rmse:0.83497
# [360]	validation_0-rmse:0.74425	validation_1-rmse:0.83490
# [361]	validation_0-rmse:0.74409	validation_1-rmse:0.83490
# [362]	validation_0-rmse:0.74387	validation_1-rmse:0.83487
# [363]	validation_0-rmse:0.74375	validation_1-rmse:0.83485
# [364]	validation_0-rmse:0.74359	validation_1-rmse:0.83485
# [365]	validation_0-rmse:0.74341	validation_1-rmse:0.83483
# [366]	validation_0-rmse:0.74331	validation_1-rmse:0.83481
# [367]	validation_0-rmse:0.74313	validation_1-rmse:0.83480
# [368]	validation_0-rmse:0.74296	validation_1-rmse:0.83479
# [369]	validation_0-rmse:0.74277	validation_1-rmse:0.83481
# [370]	validation_0-rmse:0.74254	validation_1-rmse:0.83480
# [371]	validation_0-rmse:0.74231	validation_1-rmse:0.83476
# [372]	validation_0-rmse:0.74214	validation_1-rmse:0.83476
# [373]	validation_0-rmse:0.74196	validation_1-rmse:0.83478
# [374]	validation_0-rmse:0.74181	validation_1-rmse:0.83478
# [375]	validation_0-rmse:0.74161	validation_1-rmse:0.83478
# [376]	validation_0-rmse:0.74140	validation_1-rmse:0.83474
# [377]	validation_0-rmse:0.74114	validation_1-rmse:0.83463
# [378]	validation_0-rmse:0.74090	validation_1-rmse:0.83462
# [379]	validation_0-rmse:0.74071	validation_1-rmse:0.83460
# [380]	validation_0-rmse:0.74053	validation_1-rmse:0.83458
# [381]	validation_0-rmse:0.74039	validation_1-rmse:0.83459
# [382]	validation_0-rmse:0.74020	validation_1-rmse:0.83456
# [383]	validation_0-rmse:0.74000	validation_1-rmse:0.83453
# [384]	validation_0-rmse:0.73989	validation_1-rmse:0.83454
# [385]	validation_0-rmse:0.73967	validation_1-rmse:0.83452
# [386]	validation_0-rmse:0.73947	validation_1-rmse:0.83453
# [387]	validation_0-rmse:0.73929	validation_1-rmse:0.83453
# [388]	validation_0-rmse:0.73914	validation_1-rmse:0.83452
# [389]	validation_0-rmse:0.73893	validation_1-rmse:0.83452
# [390]	validation_0-rmse:0.73872	validation_1-rmse:0.83447
# [391]	validation_0-rmse:0.73854	validation_1-rmse:0.83445
# [392]	validation_0-rmse:0.73836	validation_1-rmse:0.83446
# [393]	validation_0-rmse:0.73816	validation_1-rmse:0.83443
# [394]	validation_0-rmse:0.73796	validation_1-rmse:0.83440
# [395]	validation_0-rmse:0.73777	validation_1-rmse:0.83442
# [396]	validation_0-rmse:0.73760	validation_1-rmse:0.83442
# [397]	validation_0-rmse:0.73746	validation_1-rmse:0.83440
# [398]	validation_0-rmse:0.73728	validation_1-rmse:0.83442
# [399]	validation_0-rmse:0.73715	validation_1-rmse:0.83444
# [400]	validation_0-rmse:0.73696	validation_1-rmse:0.83442
# [401]	validation_0-rmse:0.73678	validation_1-rmse:0.83439
# [402]	validation_0-rmse:0.73663	validation_1-rmse:0.83436
# [403]	validation_0-rmse:0.73651	validation_1-rmse:0.83437
# [404]	validation_0-rmse:0.73634	validation_1-rmse:0.83436
# [405]	validation_0-rmse:0.73619	validation_1-rmse:0.83439
# [406]	validation_0-rmse:0.73599	validation_1-rmse:0.83439
# [407]	validation_0-rmse:0.73579	validation_1-rmse:0.83440
# [408]	validation_0-rmse:0.73559	validation_1-rmse:0.83440
# [409]	validation_0-rmse:0.73544	validation_1-rmse:0.83439
# [410]	validation_0-rmse:0.73524	validation_1-rmse:0.83439
# [411]	validation_0-rmse:0.73503	validation_1-rmse:0.83437
# [412]	validation_0-rmse:0.73489	validation_1-rmse:0.83438
# [413]	validation_0-rmse:0.73473	validation_1-rmse:0.83442
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None,
#              learning_rate=<function learning_rate_scheduler_xgb at 0x7849b1fa4b80>,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
import joblib
# Save the model
joblib.dump(model_xgb, "xgboost_sklearn.pkl")
# Out:
# ['xgboost_sklearn.pkl']

# %% [markdown]
# # Submission
#
# See [Jane Street RMF Demo Submission](https://www.kaggle.com/code/ryanholbrook/jane-street-rmf-demo-submission) for details.
#
# Depending on the size of your training set, you will need an [inference notebook](https://www.kaggle.com/code/regisvargas/inference-jane-street-a-beginner-s-notebook).

# %%
import os
import polars as pl
import kaggle_evaluation.jane_street_inference_server

# %%
import polars as pl
import numpy as np
# Assuming `model` is your trained model
# Assuming features required by the model are named 'feature_00', 'feature_01', etc.
def predict(test: pl.DataFrame, lags: pl.DataFrame | None) -> pl.DataFrame | pd.DataFrame:
    """Make a prediction."""
    global lags_
    if lags is not None:
        lags_ = lags
    # Extract the features for the model input
    feature_columns = [col for col in test.columns if col.startswith("feature_")]
    features = test.select(feature_columns).to_numpy()  # Convert to numpy array for model input
    features = np.nan_to_num(features, nan=0.0, posinf=0.0, neginf=0.0)
    # Generate predictions using the model
    #model_predictions = model.predict(features)
    if Is_keras:
        responder_6_predictions = model.predict(features)[:,0]
    else:
        responder_6_predictions = model_xgb.predict(features)
   # print(responder_6_predictions)    
    #responder_6_predictions = model_predictions[:, 6]  # Assuming responder_6 is at index 6
    # Create a new Polars DataFrame with row_id and responder_6 predictions
    predictions = test.select("row_id").with_columns(
        pl.Series("responder_6", responder_6_predictions)
    )
    print(predictions)
    # Ensure the output format and length requirements
    if isinstance(predictions, pl.DataFrame):
        assert predictions.columns == ['row_id', 'responder_6']
    elif isinstance(predictions, pd.DataFrame):
        assert (predictions.columns == ['row_id', 'responder_6']).all()
    else:
        raise TypeError('The predict function must return a DataFrame')
    
    assert len(predictions) == len(test)
    return predictions

# %%
inference_server = kaggle_evaluation.jane_street_inference_server.JSInferenceServer(predict)
if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
    inference_server.serve()
else:
    inference_server.run_local_gateway(
        (
            '/kaggle/input/jane-street-real-time-market-data-forecasting/test.parquet',
            '/kaggle/input/jane-street-real-time-market-data-forecasting/lags.parquet',
        )
    )
# Out:
# shape: (39, 2)
# ┌────────┬─────────────┐
# │ row_id ┆ responder_6 │
# │ ---    ┆ ---         │
# │ i64    ┆ f32         │
# ╞════════╪═════════════╡
# │ 0      ┆ 0.083174    │
# │ 1      ┆ 0.083174    │
# │ 2      ┆ 0.083174    │
# │ 3      ┆ 0.083174    │
# │ 4      ┆ 0.083174    │
# │ …      ┆ …           │
# │ 34     ┆ 0.083174    │
# │ 35     ┆ 0.083174    │
# │ 36     ┆ 0.083174    │
# │ 37     ┆ 0.083174    │
# │ 38     ┆ 0.083174    │
# └────────┴─────────────┘
